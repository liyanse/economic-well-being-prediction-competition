# %% [markdown]
# # In this notebook, we'll practice some Explanatory Data Analysis on the Train Test

# %%
import pandas as pd

# %%
train = pd.read_csv(r'C:\Users\shee\Desktop\Umoja Hack Zindi\economic-well-being-prediction-competition\Train.csv')
print(train.shape)
train.head()
# Out:
# (21454, 19)
#             ID     country  year urban_or_rural  ghsl_water_surface  \
# 0  ID_AAIethGy    Ethiopia  2016              R                 0.0
# 1  ID_AAYiaCeL    Ethiopia  2005              R                 0.0
# 2  ID_AAdurmKj  Mozambique  2009              R                 0.0
# 3  ID_AAgNHles      Malawi  2015              R                 0.0
# 4  ID_AAishfND      Guinea  2012              U                 0.0
#
#    ghsl_built_pre_1975  ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# 0             0.000000                 0.000000                 0.000055
# 1             0.000000                 0.000110                 0.000000
# 2             0.000000                 0.000000                 0.000000
# 3             0.000141                 0.000181                 0.000254
# 4             0.011649                 0.017560                 0.017383
#
#    ghsl_built_2000_to_2014  ghsl_not_built_up  ghsl_pop_density  \
# ...

# %%
#From this analysis, the train set has the target variable that is our dependent variable
train.info
# Out:
# <bound method DataFrame.info of                 ID     country  year urban_or_rural  ghsl_water_surface  \
# 0      ID_AAIethGy    Ethiopia  2016              R                 0.0
# 1      ID_AAYiaCeL    Ethiopia  2005              R                 0.0
# 2      ID_AAdurmKj  Mozambique  2009              R                 0.0
# 3      ID_AAgNHles      Malawi  2015              R                 0.0
# 4      ID_AAishfND      Guinea  2012              U                 0.0
# ...            ...         ...   ...            ...                 ...
# 21449  ID_zzPvDPjQ     Nigeria  2013              R                 0.0
# 21450  ID_zzQoPhjZ     Senegal  2011              R                 0.0
# 21451  ID_zzQuWZBF       Ghana  2014              R                 0.0
# 21452  ID_zzqCGLvb       Ghana  2014              R                 0.0
# 21453  ID_zzqQlHgY  Mozambique  2011              R                 0.0
#
# ...

# %%
train.describe()
# Out:
#                year  ghsl_water_surface  ghsl_built_pre_1975  \
# count  21454.000000        21454.000000         21454.000000
# mean    2010.060874            0.028259             0.038222
# std        4.799579            0.097490             0.113562
# min     1994.000000            0.000000             0.000000
# 25%     2008.000000            0.000000             0.000000
# 50%     2011.000000            0.000000             0.000198
# 75%     2014.000000            0.000000             0.007987
# max     2016.000000            0.969956             0.877116
#
#        ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# count             21454.000000             21454.000000
# mean                  0.028644                 0.012689
# std                   0.077367                 0.032745
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000043
# 50%                   0.000709                 0.001001
# ...

# %%
#Let us check to see if there are any missing values
train.isna().sum()
#Yass! there are no missing values
# Out:
# ID                                         0
# country                                    0
# year                                       0
# urban_or_rural                             0
# ghsl_water_surface                         0
# ghsl_built_pre_1975                        0
# ghsl_built_1975_to_1990                    0
# ghsl_built_1990_to_2000                    0
# ghsl_built_2000_to_2014                    0
# ghsl_not_built_up                          0
# ghsl_pop_density                           0
# landcover_crops_fraction                   0
# landcover_urban_fraction                   0
# landcover_water_permanent_10km_fraction    0
# landcover_water_seasonal_10km_fraction     0
# nighttime_lights                           0
# dist_to_capital                            0
# dist_to_shoreline                          0
# Target                                     0
# dtype: int64

# %%
# Plotting the relationship between an input column and the target
#I'll prefer to understand what countries are lagging behind on their construction and infrastructure.
train.plot(x='ghsl_not_built_up', y='Target', kind='scatter', alpha=0.2)
# Out:
# <AxesSubplot:xlabel='ghsl_not_built_up', ylabel='Target'>

# %%
train.plot(x='landcover_urban_fraction', y='Target', kind='scatter', alpha=0.2)
# Out:
# <AxesSubplot:xlabel='landcover_urban_fraction', ylabel='Target'>

# %% [markdown]
# #As exoected, the countries with low urban landcover and poor infrastructure and less wealthier

# %%
train.boxplot(by='urban_or_rural', column='Target', figsize=(12, 8))
# Out:
# <AxesSubplot:title={'center':'Target'}, xlabel='urban_or_rural'>
